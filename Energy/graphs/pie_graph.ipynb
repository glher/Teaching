# %%
# Installed Capacity

import matplotlib.pyplot as plt

def my_autopct(pct):
    return ('%1.1f%%' % pct) if pct > 3 else ''


# def my_label(labels):
#     return () if pct > 3 else ''
# Pie chart
labels = ['Nuclear', 'Hydroelectric', 'Wind', 'Natural Gas', 'Solar', '', 'Other', '']
sizes = [45.1, 18.9, 13.0, 9.3, 7.6, 2.5, 2.1, 1.6]

#colors
colors = ['#99ff99','#66b3ff','#95d7e6', '#ff9999','#ffcc99', '#944a2f', '#717275','#b8ac88']
 
fig1, ax1 = plt.subplots()
# explode = (0.05,0.05,0.05,0.05,0.05,0.05, 0.05, 0.05)
explode = (0,0,0,0,0,0,0,0)
ax1.pie(sizes, colors=colors, labels=labels, autopct=my_autopct, pctdistance=0.85, startangle=90, explode=explode)
#draw circle
# plt.legend(labels, loc='center left', bbox_to_anchor=(-0.1, 1.),
#            fontsize=8)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.savefig('installed_capacity.png')

# %%
# Installed Capacity

import matplotlib.pyplot as plt

def my_autopct(pct):
    return ('%1.1f%%' % pct) if pct > 2 else ''


# def my_label(labels):
#     return () if pct > 3 else ''
# Pie chart
labels = ['Nuclear', 'Hydroelectric', 'Wind', 'Natural Gas', 'Solar', '', 'Other', '']
sizes = [67.1, 13.0, 7.9, 6.9, 2.5, 1.9, 0.3, 0.3]

#colors
colors = ['#99ff99','#66b3ff','#95d7e6', '#ff9999','#ffcc99', '#b8ac88', '#944a2f', '#717275']
 
fig1, ax1 = plt.subplots()
# explode = (0.05,0.05,0.05,0.05,0.05,0.05, 0.05, 0.05)
explode = (0,0,0,0,0,0,0,0)
ax1.pie(sizes, colors=colors, labels=labels, autopct=my_autopct, pctdistance=0.85, startangle=90, explode=explode)
#draw circle
# plt.legend(labels, loc='center left', bbox_to_anchor=(-0.1, 1.),
#            fontsize=8)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.savefig('annual_production.png')

# %%
import matplotlib.pyplot as plt

x = ['Nuclear', 'Solar', 'Onshore Wind', 'Offshore Wind']
y = [7100, 940, 1436, 4077]
sizes = [50, 50, 50, 50]
plt.scatter(x, y, marker="o", s=sizes)
plt.ylabel('$ per kW')
plt.tight_layout()
plt.savefig('technology_costs.png')
